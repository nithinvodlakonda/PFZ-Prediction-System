# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel(r'C:\Users\vodla\Downloads\Incois\Kerla_VNPillai_FishCatchData_final.xls')

# %%
data
# Out:
#      Fid  Exp No.     Type  SectorId      StationName  Pi_Id  \
# 0      1       19      Pfz         5           Kollam      7
# 1      2       19  Non-Pfz         5           Kollam      7
# 2      3       20      Pfz         5        Edamuttom      7
# 3      4       20  Non-Pfz         5        Edamuttom      7
# 4      5       21      Pfz         5       Neendakara      7
# ..   ...      ...      ...       ...              ...    ...
# 161  162       97  Non-Pfz         5   Ramancheritura      7
# 162  163       98      Pfz         5        Edamuttom      7
# 163  164       98  Non-Pfz         5        Edamuttom      7
# 164  165       99      Pfz         5         Munambam      7
# 165  166       99  Non-Pfz         5         Munambam      7
#
#          Date_Of_Fishing Time_Of_Departure Arrival_Time Duration_Total  ...  \
# 0    2008-03-04 00:00:00               NaN          NaN            NaN  ...
# 1    2008-03-04 00:00:00               NaN          NaN            NaN  ...
# ...

# %%
data.columns
# Out:
# Index(['Fid', 'Exp No.', 'Type', 'SectorId', 'StationName', 'Pi_Id',
#        'Date_Of_Fishing', 'Time_Of_Departure', 'Arrival_Time',
#        'Duration_Total', 'Name_Of_Vessel', 'Type_Of_Boat', 'Boat_Length',
#        'Net_Type', 'pfzLatitude', 'pfzLongitude', 'pfzAngle', 'pfzDirection',
#        'pfzDistance', 'pfzDepth', 'ValidityDate', 'Forcast_ReceivedOn',
#        'Longitude', 'Latitude', 'Distance', 'Direction', 'Angle (Deg)',
#        'Depth (m)', 'Fishing Hours', 'No of Hauls', 'No of Fishermen',
#        'No of Boats', 'MajorSpecies_Caught', 'Unnamed: 33', 'Total_Catch',
#        'Avg. Length', 'Staus_Of_Catch', 'Total_Expenditure', 'Fuel', 'wages',
#        'Other_Expenses', 'Approximate cost', 'status of sea', 'status of sky',
#        'Wind Direction', 'Sea Surface Temperature', 'OceanColour',
#        'PlanktonVolume', 'Chl_Concentration', 'Nitrate', 'Nitrite', 'Ammonia',
#        'Slicate', 'Phosphate'],
#       dtype='object')

# %%
final=data[['Date_Of_Fishing','Latitude','Longitude','Total_Catch']].copy()

# %%
final
# Out:
#          Date_Of_Fishing   Latitude  Longitude  Total_Catch
# 0    2008-03-04 00:00:00   8.850000  76.466667       1700.0
# 1    2008-03-04 00:00:00   8.866667  76.516667        350.0
# 2    2008-03-05 00:00:00  10.250000  76.083333       4800.0
# 3    2008-03-05 00:00:00  10.166667  76.150000        700.0
# 4    2008-05-27 00:00:00   8.916667  76.500000       2100.0
# ..                   ...        ...        ...          ...
# 161  2011-06-02 00:00:00   9.166667  76.166667        210.0
# 162  2011-06-10 00:00:00  10.350000  75.833333       1200.0
# 163  2011-06-10 00:00:00  10.450000  75.833333        300.0
# 164  2011-06-15 00:00:00  10.333333  75.866667        950.0
# 165  2011-06-15 00:00:00  10.333333  75.866667        175.0
#
# [166 rows x 4 columns]

# %%
final[final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date_Of_Fishing, Latitude, Longitude, Total_Catch]
# Index: []

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_Of_Fishing  166 non-null    object
#  1   Latitude         162 non-null    float64
#  2   Longitude        162 non-null    float64
#  3   Total_Catch      163 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.3+ KB

# %%
final[final[['Latitude','Longitude']].isnull().any(axis=1)]
# Out:
#         Date_Of_Fishing  Latitude  Longitude  Total_Catch
# 48  2009-07-03 00:00:00       NaN        NaN       2500.0
# 49  2009-07-03 00:00:00       NaN        NaN        450.0
# 50  2009-07-13 00:00:00       NaN        NaN       1800.0
# 51  2009-07-13 00:00:00       NaN        NaN        200.0

# %%
final[final['Total_Catch'].isnull()]
# Out:
#         Date_Of_Fishing  Latitude  Longitude  Total_Catch
# 12  2008-10-05 00:00:00  9.333333  76.366667          NaN
# 13  2008-10-05 00:00:00  9.250000  76.333333          NaN
# 14  2008-10-05 00:00:00  9.150000  76.316667          NaN

# %%
final[final['Latitude'].isin([         9.25, 9.33305555556,          9.15,  15.330353615, 15.1233000086,
 14.7523605444, 15.0275681312,         17.37,         11.55,      13.13464,
      12.08344])]
# Out:
#          Date_Of_Fishing  Latitude  Longitude  Total_Catch
# 13   2008-10-05 00:00:00      9.25  76.333333          NaN
# 14   2008-10-05 00:00:00      9.15  76.316667          NaN
# 16   2008-10-05 00:00:00      9.25  76.333333        380.0
# 17   2008-10-05 00:00:00      9.25  76.350000        700.0
# 55   2009-08-26 00:00:00      9.15  76.283333        450.0
# 153  2011-05-12 00:00:00     11.55  75.416667        210.0

# %%
final[final.duplicated(subset=['Latitude','Longitude'], keep=False)]
# Out:
#          Date_Of_Fishing   Latitude  Longitude  Total_Catch
# 12   2008-10-05 00:00:00   9.333333  76.366667          NaN
# 13   2008-10-05 00:00:00   9.250000  76.333333          NaN
# 16   2008-10-05 00:00:00   9.250000  76.333333        380.0
# 27   2009-01-21 00:00:00   9.833333  76.166667        300.0
# 29   2009-01-24 00:00:00   9.833333  76.166667        250.0
# 34   2009-03-06 00:00:00   9.966667  76.133333       1100.0
# 35   2009-03-06 00:00:00   9.966667  76.133333        600.0
# 43   2009-05-19 00:00:00   9.966667  76.166667        950.0
# 48   2009-07-03 00:00:00        NaN        NaN       2500.0
# 49   2009-07-03 00:00:00        NaN        NaN        450.0
# 50   2009-07-13 00:00:00        NaN        NaN       1800.0
# 51   2009-07-13 00:00:00        NaN        NaN        200.0
# 74   2010-02-19 00:00:00   9.966667  76.166667       5000.0
# 86   2010-05-06 00:00:00  10.166667  76.333333       1400.0
# 91   2010-08-03 00:00:00  10.166667  76.333333        130.0
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_Of_Fishing  166 non-null    object
#  1   Latitude         162 non-null    float64
#  2   Longitude        162 non-null    float64
#  3   Total_Catch      163 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.3+ KB

# %%
final
# Out:
#          Date_Of_Fishing   Latitude  Longitude  Total_Catch
# 0    2008-03-04 00:00:00   8.850000  76.466667       1700.0
# 1    2008-03-04 00:00:00   8.866667  76.516667        350.0
# 2    2008-03-05 00:00:00  10.250000  76.083333       4800.0
# 3    2008-03-05 00:00:00  10.166667  76.150000        700.0
# 4    2008-05-27 00:00:00   8.916667  76.500000       2100.0
# ..                   ...        ...        ...          ...
# 161  2011-06-02 00:00:00   9.166667  76.166667        210.0
# 162  2011-06-10 00:00:00  10.350000  75.833333       1200.0
# 163  2011-06-10 00:00:00  10.450000  75.833333        300.0
# 164  2011-06-15 00:00:00  10.333333  75.866667        950.0
# 165  2011-06-15 00:00:00  10.333333  75.866667        175.0
#
# [166 rows x 4 columns]

# %%
final['Date_Of_Fishing']=pd.to_datetime(final['Date_Of_Fishing'], errors='coerce')

# %%
final
# Out:
#     Date_Of_Fishing   Latitude  Longitude  Total_Catch
# 0        2008-03-04   8.850000  76.466667       1700.0
# 1        2008-03-04   8.866667  76.516667        350.0
# 2        2008-03-05  10.250000  76.083333       4800.0
# 3        2008-03-05  10.166667  76.150000        700.0
# 4        2008-05-27   8.916667  76.500000       2100.0
# ..              ...        ...        ...          ...
# 161      2011-06-02   9.166667  76.166667        210.0
# 162      2011-06-10  10.350000  75.833333       1200.0
# 163      2011-06-10  10.450000  75.833333        300.0
# 164      2011-06-15  10.333333  75.866667        950.0
# 165      2011-06-15  10.333333  75.866667        175.0
#
# [166 rows x 4 columns]

# %%
final[final['Total_Catch'].astype(str).str.contains(r'[a-zA-Z]', na=False, case=False)]
# Out:
#    Date_Of_Fishing  Latitude  Longitude  Total_Catch
# 12      2008-10-05  9.333333  76.366667          NaN
# 13      2008-10-05  9.250000  76.333333          NaN
# 14      2008-10-05  9.150000  76.316667          NaN

# %%
final.to_csv(r'C:\Users\vodla\Downloads\Incois\Cleaned_kerala.csv', index=False)
